# %% [markdown]
# <a href="https://colab.research.google.com/github/RedaElmar/Griffin/blob/master/Exercice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file = 'données_kidney.xlsx'
df = pd.read_excel(io=file)

# %%
df
# Out:
#      age  bp     sg  al  su  bgr  bu   sc  hemo  pcv    wc   rc
# 0     48  80  1.020   1   0  121  36  1.2  15.4   44  7800  5.2
# 1      7  50  1.020   4   0  177  18  0.8  11.3   38  6000  4.0
# 2     62  80  1.010   2   3  423  53  1.8   9.6   31  7500  4.0
# 3     48  70  1.005   4   0  117  56  3.8  11.2   32  6700  3.9
# 4     51  80  1.010   2   0  106  26  1.4  11.6   35  7300  4.6
# ..   ...  ..    ...  ..  ..  ...  ..  ...   ...  ...   ...  ...
# 295   51  80  1.020   0   0   94  25  0.8  15.0   46  9500  6.4
# 296   41  80  1.025   0   0  112  16  1.1  15.6   52  7200  5.8
# 297   52  80  1.025   0   0   99  48  1.2  14.8   52  6300  5.3
# 298   36  80  1.025   0   0   85  16  1.1  15.6   44  5800  6.3
# 299   37  60  1.020   0   0  109  47  1.1  15.0   48  7000  5.2
#
# [300 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for column in tableau.columns:
  tableau[column] = tableau[column] - tableau[column].mean()
tableau.head(10)
# Out:
#           age         bp        sg  ...   pcv       wc         rc
# 0   -3.083333   4.026667  0.001937  ...   4.4  -669.63 -64.426333
# 1  -44.083333 -25.973333  0.001937  ...  -1.6 -2469.63 -65.626333
# 2   10.916667   4.026667 -0.008063  ...  -8.6  -969.63 -65.626333
# 3   -3.083333  -5.973333 -0.013063  ...  -7.6 -1769.63 -65.726333
# 4   -0.083333   4.026667 -0.008063  ...  -4.6 -1169.63 -65.026333
# 5    8.916667  14.026667 -0.003063  ...  -0.6  -669.63 -65.226333
# 6   16.916667  -5.973333 -0.008063  ...  -3.6   551.37 -65.626333
# 7  -27.083333   2.026667 -0.003063  ...   4.4 -1569.63 -64.626333
# 8    0.916667  24.026667 -0.003063  ...  -6.6  1130.37 -65.626333
# 9    1.916667  14.026667  0.001937  ... -10.6  3630.37 -65.926333
# 10  -1.083333 -15.973333 -0.008063  ... -11.6   551.37 -65.626333
# 11  11.916667  -5.973333 -0.008063  ...  -7.6 -3969.63 -65.826333
# 12  16.916667  -5.973333 -0.003063  ... -11.6  3730.37 -66.226333
# ...

# %%
result = (1/300)*tableau.T.dot(tableau);
result
# Out:
#               age           bp  ...            wc             rc
# age    270.829722    31.408889  ...  6.472437e+03     738.379139
# bp      31.408889   174.505956  ...  1.652310e+03     818.635369
# sg      -0.023055    -0.017565  ... -3.750400e+00      -0.402221
# al       3.829722     3.904622  ...  9.023850e+02     133.809686
# su       3.564444     3.224711  ...  5.576212e+02     -27.955236
# bgr    295.267500   171.333067  ...  3.300897e+04    -665.432737
# bu     153.349167   117.724800  ...  8.957391e+03    3330.936510
# sc       8.951972     9.455742  ...  5.141833e+02     179.991905
# hemo   -10.511139    -9.822142  ... -1.687655e+03     -68.334335
# pcv    -37.636667   -34.544000  ... -5.268725e+03    -248.528467
# wc    6472.437500  1652.310133  ...  8.177605e+06 -111163.431590
# rc     738.379139   818.635369  ... -1.111634e+05  438541.351473
#
# [12 rows x 12 columns]

# %%
result2 = result

# %%
#Calcul des vecteurs et valeurs propres
import numpy.linalg as la
eval,evec=la.eig(result2.to_numpy())
eval
# Out:
# array([8.17935421e+06, 4.36976144e+05, 6.04109335e+03, 2.04338507e+03,
#        2.48208199e+02, 1.62452162e+02, 4.20200319e+01, 4.16826949e+00,
#        1.69983742e+00, 8.40505393e-01, 4.78070807e-01, 1.62671459e-05])

# %%
evec
# Out:
# array([[-7.90125384e-04,  1.90595130e-03, -5.03757394e-02,
#         -5.26585611e-02,  9.76612295e-01, -1.97296436e-01,
#          4.40825374e-02,  3.06656558e-03,  4.64564536e-03,
#         -2.66498890e-03, -2.50734067e-03,  1.77334584e-05],
#        [-2.00660765e-04,  1.93036546e-03, -3.13163395e-02,
#         -4.42737557e-02,  1.85984841e-01,  9.71211471e-01,
#          1.37890432e-01, -1.04087091e-02,  1.76166526e-03,
#          3.12968554e-03, -8.84650429e-03,  7.35696460e-06],
#        [ 4.57878426e-07, -1.04533578e-06,  3.25955262e-05,
#          3.01280719e-05, -3.35901332e-05, -4.66366251e-05,
#          3.20644007e-04, -3.05241744e-04, -7.73279055e-04,
#          1.83244442e-04,  6.90297816e-06,  9.99999584e-01],
#        [-1.10103921e-04,  3.36448295e-04, -7.25637631e-03,
#         -1.27683889e-02, -1.57944481e-03,  8.27612908e-03,
#         -5.47917043e-02,  5.98526896e-02,  2.84071612e-01,
#         -9.26920245e-01, -2.30761174e-01,  4.27905427e-04],
# ...

# %%
#Conserver les valeurs propres et leur vecteurs propres associé
#et trier les valeurs propres en ordre décroissant
eig_pairs = [(eval[i], evec[:, i]) for i in range(len(eval))]
eig_pairs.sort(key = lambda x:x[0], reverse=True)
eig_pairs
# Out:
# [(8179354.21001562,
#   array([-7.90125384e-04, -2.00660765e-04,  4.57878426e-07, -1.10103921e-04,
#          -6.82475284e-05, -4.03948427e-03, -1.08981799e-03, -6.25791861e-05,
#           2.06239275e-04,  6.43800191e-04, -9.99887582e-01,  1.43588340e-02])),
#  (436976.1442861278,
#   array([ 1.90595130e-03,  1.93036546e-03, -1.04533578e-06,  3.36448295e-04,
#          -4.55639860e-05, -4.29560116e-04,  7.95608323e-03,  4.30936856e-04,
#          -2.13316621e-04, -7.46420618e-04,  1.43490394e-02,  9.99861170e-01])),
#  (6041.093353145226,
#   array([-5.03757394e-02, -3.13163395e-02,  3.25955262e-05, -7.25637631e-03,
#          -9.86911202e-03, -9.82665027e-01, -1.69132387e-01, -9.88777727e-03,
#           1.36843624e-02,  4.23202173e-02,  4.24772687e-03,  1.05994022e-03])),
#  (2043.3850680451617,
#   array([-5.26585611e-02, -4.42737557e-02,  3.01280719e-05, -1.27683889e-02,
#           2.03752263e-03,  1.77260712e-01, -9.74409269e-01, -5.27852630e-02,
# ...

# %%
#la qualité de la représentation 𝑄𝐽 pour J=1 et J=2
Q1=eig_pairs[0][0]/(eig_pairs[0][0]+eig_pairs[1][0])
Q2=(eig_pairs[0][0]+eig_pairs[1][0])/(eig_pairs[0][0]+eig_pairs[1][0]+eig_pairs[2][0])
print("Q1 =",Q1,"\nQ2 =",Q2)
# Out:
# Q1 = 0.9492851218189463
# Q2 = 0.9992993698555184

# %%
#Prenons les 2 vecteurs propres du début de la liste (valeur propre max) pour calculer les deux composantes pricipales
eigenvec1=eig_pairs[0][1]
eigenvec2=eig_pairs[1][1]
CP1 = df_std.dot(eigenvec1)
CP2 = df_std.dot(eigenvec2)

# %%
CP1
# Out:
# 0       668.755182
# 1      2468.362406
# 2       967.444795
# 3      1768.600139
# 4      1168.752777
#           ...
# 295   -1030.916453
# 296    1268.765337
# 297    2168.665758
# 298    2668.722998
# 299    1468.717047
# Length: 300, dtype: float64

# %%
CP2
# Out:
# 0      -74.160250
# 1     -101.485484
# 2      -79.621186
# 3      -91.090494
# 4      -81.994135
#           ...
# 295    -48.639167
# 296    -82.344748
# 297    -95.477456
# 298   -101.925433
# 299    -85.609662
# Length: 300, dtype: float64

# %%
#Passer df du DataFrame vers un objet array
dfarray=df.to_numpy()

# %%
PartInertie=CP1[12]*CP1[12]/(dfarray[12,:].T.dot(dfarray[12,:]))
print("la part d’inertie d’un individu 12 par rapport à l'axe U1\nPI =",PartInertie)
# Out:
# la part d’inertie d’un individu 12 par rapport à l'axe U1
# PI = 0.09349832802950554

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(CP1,CP2)
ax.set_title('REPRÉSENTATION DES INDIVIDUS')
ax.set_xlabel('Composante Principale 1', fontsize = 15)
ax.set_ylabel('Componente Principale 2', fontsize = 15)
ax.axhline(y=0, color="black", linestyle=":")
ax.axvline(x=0, color="black", linestyle=":")
plt.grid()
plt.axis([-10000, 10000, -180, 180])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
for i in range(df.shape[1]):
  x = np.corrcoef(CP1,df[df.columns[i]])[0,1]
  y = np.corrcoef(CP2,df[df.columns[i]])[0,1]
  ax.annotate("", xy= (x,y), xytext=(0, 0),arrowprops=dict(arrowstyle="->"))
  ax.annotate(df.columns[i], (x+0.02,y+0.02), size=12)
ax.set_title('REPRÉSENTATION DES VARIABLES : Correlation circle')
ax.axhline(y=0, color="black", linestyle=":")
ax.axvline(x=0, color="black", linestyle=":")
an = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(an), np.sin(an))
plt.axis('equal')
plt.show()

# %%
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc
# !pip install pypandoc
# !jupyter nbconvert --to PDF "Exercice3.ipynb"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pandoc is already the newest version (1.19.2.4~dfsg-1build4).
# pandoc set to manually installed.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
# Suggested packages:
#   fonts-noto apache2 | lighttpd | httpd poppler-utils ghostscript
# ...
